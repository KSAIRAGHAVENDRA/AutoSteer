# %%
# %run augment.py
# Out:
# processed 0 images
# processed 1000 images
# processed 2000 images
# processed 3000 images
# processed 4000 images
# processed 5000 images
# processed 6000 images
# processed 7000 images
# processed 8000 images
# processed 9000 images
# processed 10000 images
# processed 11000 images
# processed 12000 images
# processed 13000 images
# processed 14000 images
# processed 15000 images
# mirrored 0 images
# mirrored 1000 images
# mirrored 2000 images
# mirrored 3000 images
# mirrored 4000 images
# mirrored 5000 images
# mirrored 6000 images
# mirrored 7000 images
# mirrored 8000 images
# mirrored 9000 images
# mirrored 10000 images
# mirrored 11000 images
# mirrored 12000 images

# %%
# %run preprocess.py
# Out:
# Pre-processing validation data set3...
# Processed 0 images...
# Processed 1000 images...
# Processed 2000 images...
# Processed 3000 images...
# Processed 4000 images...
# Processed 5000 images...
# Pre-processing test data set...
# Processed 0 images...
# Processed 1000 images...
# Processed 2000 images...
# Processed 3000 images...

# %%
# %run train.py
# Out:
# Using TensorFlow backend.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17363167703066236938
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4945621811
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7680461345358625377
# physical_device_desc: "device: 0, name: GeForce GTX 1060 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# Loading training data...
# Data path: E:/nvidia4/data/X_train_preprocess.npy
# X_train shape:(20219, 192, 256, 3)
# X_test shape:(5055, 192, 256, 3)
# y_train shape:(20219,)
# y_test shape:(5055,)
# Computing training set mean...
# Saving training set mean...
# Creating model...
# WARNING:tensorflow:From C:\Users\DELL\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# %run predict.py
# Out:
# Using TensorFlow backend.
# Loading model...
# Loading training data mean...
# Reading test data...
# Predicting...
# Writing predictions...
# Done!
# Calculating RMSE
# Predicted angles: 3159
# 104.219174632
# 0.0329911917163
# model evaluated RMSE: 0.181634775625

# %%
# %run vizualize.py
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# %run plot.py

# %%
# %run predict.py
# Out:
# Loading model...
# Loading training data mean...
# Reading test data...
# Predicting...
# Writing predictions...
# Done!
